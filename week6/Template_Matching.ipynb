# %%
import os
import numpy as np
from skimage.io import imread, imsave
import matplotlib.pyplot as plt
from skimage.feature import match_template

# %%
! gdown "1NRNlFMlR4k0SuHtRStphIx5O1mGqZMLR" -O "imagen1.png"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1NRNlFMlR4k0SuHtRStphIx5O1mGqZMLR
# To: c:\Users\jayka\OneDrive\Documentos\Courses\image-processing\week6\imagen1.png
#
#   0%|          | 0.00/895k [00:00<?, ?B/s]
#  59%|█████▊    | 524k/895k [00:00<00:00, 3.10MB/s]
# 100%|██████████| 895k/895k [00:00<00:00, 4.78MB/s]

# %%
! gdown "1ioMyX7_-Z2mdIpxhdtZgss9t9xFHYd9g" -O "imagen2.png"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ioMyX7_-Z2mdIpxhdtZgss9t9xFHYd9g
# To: c:\Users\jayka\OneDrive\Documentos\Courses\image-processing\week6\imagen2.png
#
#   0%|          | 0.00/31.4k [00:00<?, ?B/s]
# 100%|██████████| 31.4k/31.4k [00:00<00:00, 1.57MB/s]

# %%
im = imread('imagen1.png')
im_waldo = imread('imagen2.png')

# %% [markdown]
# ### 1. Cargar las imágenes

# %%
plt.imshow(im[:,:,:])

# %%
plt.imshow(im_waldo)

# %%
plt.imshow(im_waldo[:,:,0], cmap="gray")

# %% [markdown]
# ### 3. Obtengamos el template matching
#
# Recuede que puede usar la función `match_template`. Hint: Si queremos tener la imágen resultante del mismo tamaño de la imagen original, podemos usar `pad_input=True`

# %%
plt.figure(figsize=(20,10))
plt.imshow(match_template(im[:,:,0], im_waldo[:,:,0], pad_input=True), cmap='gray')
plt.colorbar()

# %% [markdown]
# ### 4. Obtengamos la posición de mayor valor, y recortemos +/-100 pixeles alrededor. Mostrar la imagen

# %%
# completar aquí

# %% [markdown]
# ## Reto
#
# ### Encontrar a Waldo aquí

# %%
! gdown "194ZXDFmvqWiINLRTMLRptPzpcPm6PZK8" -O "imagen3.png"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=194ZXDFmvqWiINLRTMLRptPzpcPm6PZK8
# To: c:\Users\jayka\OneDrive\Documentos\Courses\image-processing\week6\imagen3.png
#
#   0%|          | 0.00/2.42M [00:00<?, ?B/s]
#  22%|██▏       | 524k/2.42M [00:00<00:00, 3.50MB/s]
# 100%|██████████| 2.42M/2.42M [00:00<00:00, 10.5MB/s]

# %%
! gdown "1bOcV3KC607dtcuW8guO_7XEgyK7LMZrq" -O "imagen4.png"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1bOcV3KC607dtcuW8guO_7XEgyK7LMZrq
# To: c:\Users\jayka\OneDrive\Documentos\Courses\image-processing\week6\imagen4.png
#
#   0%|          | 0.00/15.4k [00:00<?, ?B/s]
# 100%|██████████| 15.4k/15.4k [00:00<00:00, 46.0MB/s]

# %%
im = imread('imagen3.png')
im_waldo = imread('imagen4.png')

# %%
plt.imshow(im)

# %%
plt.imshow(im_waldo)

# %%
result = match_template(im[:,:,0], im_waldo[:,:,0], pad_input=True)
center = np.where(result == np.amax(result))
res = im[center[0][0]-50:center[0][0] + 50, center[1][0]-50:center[1][0]+50]
plt.imshow(res)
